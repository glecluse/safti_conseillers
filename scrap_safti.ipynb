# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# # Collecte des données

# %% [markdown]
# ## Collecte des liens du site

# %%
liens = []
nombre_de_pages = int(input('Combien de pages contient la liste des conseillers ?'))
for i in range(nombre_de_pages +1):
    liens.append('https://www.safti.fr/trouver-un-conseiller?page='+str(i))
liens.pop(0)
liens

# %% [markdown]
# ## Collecte des listes conseillers, villes, telephone, lien de la photo, lien du ministe

# %%
liste_conseillers = []
liste_villes = []
liste_telephone = []
liste_lien_photo = []
liste_lien_minisite = []

h = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Language': 'fr-FR,fr;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1'
    }


for page_url in liens:
    print(f"traitement de la page {liens.index(page_url)+1} sur {len(liens)}")
    response = requests.get(page_url, headers=h)
    if response.status_code != 200:
        print(f"Erreur lors du chargement de la page {page_url} avec le code {response.status_code}.")
        continue  

    soup = BeautifulSoup(response.content, 'html.parser')

    conseillers = soup.find_all('a', attrs={"data-testid": "agent-card-name"})
    villes = soup.find_all('p', class_="saf-p-0 saf-text-[14px] saf-font-medium saf-text-primary")
    telephones = soup.find_all('a', {'data-testid': 'trouverunconseiller-phone-button'})
    images = soup.find_all('img', {'class': 'rounded-circle'})

    # Process each found item
    for i, conseiller in enumerate(conseillers):
        liste_conseillers.append(conseiller.text.strip())
        liste_villes.append(villes[i].text.strip() if i < len(villes) else 'non renseigné')
        liste_lien_photo.append(images[i].get('src', 'non renseigné') if i < len(images) else 'non renseigné')
        liste_lien_minisite.append(conseiller.get('href', 'non renseigné'))        
       
        phone_number = 'non renseigné'  
        if i < len(telephones):
            phone_href = telephones[i].get('href', '')
            if 'tel:' in phone_href:
                phone_number = phone_href.split('tel:')[-1]
        liste_telephone.append(phone_number)

base_url = "https://www.safti.fr"
liste_lien_minisite = [base_url + link if link != 'non renseigné' else 'non renseigné' for link in liste_lien_minisite]
# Out:
# traitement de la page 1 sur 631
# traitement de la page 2 sur 631
# traitement de la page 3 sur 631
# traitement de la page 4 sur 631
# traitement de la page 5 sur 631
# traitement de la page 6 sur 631
# traitement de la page 7 sur 631
# traitement de la page 8 sur 631
# traitement de la page 9 sur 631
# traitement de la page 10 sur 631
# traitement de la page 11 sur 631
# traitement de la page 12 sur 631
# traitement de la page 13 sur 631
# traitement de la page 14 sur 631
# traitement de la page 15 sur 631
# traitement de la page 16 sur 631
# traitement de la page 17 sur 631
# traitement de la page 18 sur 631
# traitement de la page 19 sur 631
# traitement de la page 20 sur 631
# traitement de la page 21 sur 631
# traitement de la page 22 sur 631
# traitement de la page 23 sur 631
# traitement de la page 24 sur 631
# traitement de la page 25 sur 631
# traitement de la page 26 sur 631
# traitement de la page 27 sur 631
# traitement de la page 28 sur 631
# traitement de la page 29 sur 631
# traitement de la page 30 sur 631
# traitement de la page 31 sur 631
# traitement de la page 32 sur 631
# traitement de la page 33 sur 631
# traitement de la page 34 sur 631
# traitement de la page 35 sur 631
# traitement de la page 36 sur 631
# traitement de la page 37 sur 631
# traitement de la page 38 sur 631
# traitement de la page 39 sur 631
# traitement de la page 40 sur 631
# traitement de la page 41 sur 631
# traitement de la page 42 sur 631
# traitement de la page 43 sur 631
# traitement de la page 44 sur 631
# traitement de la page 45 sur 631
# traitement de la page 46 sur 631
# traitement de la page 47 sur 631
# traitement de la page 48 sur 631
# traitement de la page 49 sur 631
# traitement de la page 50 sur 631
# traitement de la page 51 sur 631
# traitement de la page 52 sur 631
# traitement de la page 53 sur 631
# traitement de la page 54 sur 631
# traitement de la page 55 sur 631
# traitement de la page 56 sur 631
# traitement de la page 57 sur 631
# traitement de la page 58 sur 631
# traitement de la page 59 sur 631
# traitement de la page 60 sur 631
# traitement de la page 61 sur 631
# traitement de la page 62 sur 631
# traitement de la page 63 sur 631
# traitement de la page 64 sur 631
# traitement de la page 65 sur 631
# traitement de la page 66 sur 631
# traitement de la page 67 sur 631
# traitement de la page 68 sur 631
# traitement de la page 69 sur 631
# traitement de la page 70 sur 631
# traitement de la page 71 sur 631
# traitement de la page 72 sur 631
# traitement de la page 73 sur 631
# traitement de la page 74 sur 631
# traitement de la page 75 sur 631
# traitement de la page 76 sur 631
# traitement de la page 77 sur 631
# traitement de la page 78 sur 631
# traitement de la page 79 sur 631
# traitement de la page 80 sur 631
# traitement de la page 81 sur 631
# traitement de la page 82 sur 631
# traitement de la page 83 sur 631
# traitement de la page 84 sur 631
# traitement de la page 85 sur 631
# traitement de la page 86 sur 631
# traitement de la page 87 sur 631
# traitement de la page 88 sur 631
# traitement de la page 89 sur 631
# traitement de la page 90 sur 631
# traitement de la page 91 sur 631
# traitement de la page 92 sur 631
# traitement de la page 93 sur 631
# traitement de la page 94 sur 631
# traitement de la page 95 sur 631
# traitement de la page 96 sur 631
# traitement de la page 97 sur 631
# traitement de la page 98 sur 631
# traitement de la page 99 sur 631
# traitement de la page 100 sur 631
# traitement de la page 101 sur 631
# traitement de la page 102 sur 631
# traitement de la page 103 sur 631
# traitement de la page 104 sur 631
# traitement de la page 105 sur 631
# traitement de la page 106 sur 631
# traitement de la page 107 sur 631
# traitement de la page 108 sur 631
# traitement de la page 109 sur 631
# traitement de la page 110 sur 631
# traitement de la page 111 sur 631
# traitement de la page 112 sur 631
# traitement de la page 113 sur 631
# traitement de la page 114 sur 631
# traitement de la page 115 sur 631
# traitement de la page 116 sur 631
# traitement de la page 117 sur 631
# traitement de la page 118 sur 631
# traitement de la page 119 sur 631
# traitement de la page 120 sur 631
# traitement de la page 121 sur 631
# traitement de la page 122 sur 631
# traitement de la page 123 sur 631
# traitement de la page 124 sur 631
# traitement de la page 125 sur 631
# traitement de la page 126 sur 631
# traitement de la page 127 sur 631
# traitement de la page 128 sur 631
# traitement de la page 129 sur 631
# traitement de la page 130 sur 631
# traitement de la page 131 sur 631
# traitement de la page 132 sur 631
# traitement de la page 133 sur 631
# traitement de la page 134 sur 631
# traitement de la page 135 sur 631
# traitement de la page 136 sur 631
# traitement de la page 137 sur 631
# traitement de la page 138 sur 631
# traitement de la page 139 sur 631
# traitement de la page 140 sur 631
# traitement de la page 141 sur 631
# traitement de la page 142 sur 631
# traitement de la page 143 sur 631
# traitement de la page 144 sur 631
# traitement de la page 145 sur 631
# traitement de la page 146 sur 631
# traitement de la page 147 sur 631
# traitement de la page 148 sur 631
# traitement de la page 149 sur 631
# traitement de la page 150 sur 631
# traitement de la page 151 sur 631
# traitement de la page 152 sur 631
# traitement de la page 153 sur 631
# traitement de la page 154 sur 631
# traitement de la page 155 sur 631
# traitement de la page 156 sur 631
# traitement de la page 157 sur 631
# traitement de la page 158 sur 631
# traitement de la page 159 sur 631
# traitement de la page 160 sur 631
# traitement de la page 161 sur 631
# traitement de la page 162 sur 631
# traitement de la page 163 sur 631
# traitement de la page 164 sur 631
# traitement de la page 165 sur 631
# traitement de la page 166 sur 631
# traitement de la page 167 sur 631
# traitement de la page 168 sur 631
# traitement de la page 169 sur 631
# traitement de la page 170 sur 631
# traitement de la page 171 sur 631
# traitement de la page 172 sur 631
# traitement de la page 173 sur 631
# traitement de la page 174 sur 631
# traitement de la page 175 sur 631
# traitement de la page 176 sur 631
# traitement de la page 177 sur 631
# traitement de la page 178 sur 631
# traitement de la page 179 sur 631
# traitement de la page 180 sur 631
# traitement de la page 181 sur 631
# traitement de la page 182 sur 631
# traitement de la page 183 sur 631
# traitement de la page 184 sur 631
# traitement de la page 185 sur 631
# traitement de la page 186 sur 631
# traitement de la page 187 sur 631
# traitement de la page 188 sur 631
# traitement de la page 189 sur 631
# traitement de la page 190 sur 631
# traitement de la page 191 sur 631
# traitement de la page 192 sur 631
# traitement de la page 193 sur 631
# traitement de la page 194 sur 631
# traitement de la page 195 sur 631
# traitement de la page 196 sur 631
# traitement de la page 197 sur 631
# traitement de la page 198 sur 631
# traitement de la page 199 sur 631
# traitement de la page 200 sur 631
# traitement de la page 201 sur 631
# traitement de la page 202 sur 631
# traitement de la page 203 sur 631
# traitement de la page 204 sur 631
# traitement de la page 205 sur 631
# traitement de la page 206 sur 631
# traitement de la page 207 sur 631
# traitement de la page 208 sur 631
# traitement de la page 209 sur 631
# traitement de la page 210 sur 631
# traitement de la page 211 sur 631
# traitement de la page 212 sur 631
# traitement de la page 213 sur 631
# traitement de la page 214 sur 631
# traitement de la page 215 sur 631
# traitement de la page 216 sur 631
# traitement de la page 217 sur 631
# traitement de la page 218 sur 631
# traitement de la page 219 sur 631
# traitement de la page 220 sur 631
# traitement de la page 221 sur 631
# traitement de la page 222 sur 631
# traitement de la page 223 sur 631
# traitement de la page 224 sur 631
# traitement de la page 225 sur 631
# traitement de la page 226 sur 631
# traitement de la page 227 sur 631
# traitement de la page 228 sur 631
# traitement de la page 229 sur 631
# traitement de la page 230 sur 631
# traitement de la page 231 sur 631
# traitement de la page 232 sur 631
# traitement de la page 233 sur 631
# traitement de la page 234 sur 631
# traitement de la page 235 sur 631
# traitement de la page 236 sur 631
# traitement de la page 237 sur 631
# traitement de la page 238 sur 631
# traitement de la page 239 sur 631
# traitement de la page 240 sur 631
# traitement de la page 241 sur 631
# traitement de la page 242 sur 631
# traitement de la page 243 sur 631
# traitement de la page 244 sur 631
# traitement de la page 245 sur 631
# traitement de la page 246 sur 631
# traitement de la page 247 sur 631
# traitement de la page 248 sur 631
# traitement de la page 249 sur 631
# traitement de la page 250 sur 631
# traitement de la page 251 sur 631
# traitement de la page 252 sur 631
# traitement de la page 253 sur 631
# traitement de la page 254 sur 631
# traitement de la page 255 sur 631
# traitement de la page 256 sur 631
# traitement de la page 257 sur 631
# traitement de la page 258 sur 631
# traitement de la page 259 sur 631
# traitement de la page 260 sur 631
# traitement de la page 261 sur 631
# traitement de la page 262 sur 631
# traitement de la page 263 sur 631
# traitement de la page 264 sur 631
# traitement de la page 265 sur 631
# traitement de la page 266 sur 631
# traitement de la page 267 sur 631
# traitement de la page 268 sur 631
# traitement de la page 269 sur 631
# traitement de la page 270 sur 631
# traitement de la page 271 sur 631
# traitement de la page 272 sur 631
# traitement de la page 273 sur 631
# traitement de la page 274 sur 631
# traitement de la page 275 sur 631
# traitement de la page 276 sur 631
# traitement de la page 277 sur 631
# traitement de la page 278 sur 631
# traitement de la page 279 sur 631
# traitement de la page 280 sur 631
# traitement de la page 281 sur 631
# traitement de la page 282 sur 631
# traitement de la page 283 sur 631
# traitement de la page 284 sur 631
# traitement de la page 285 sur 631
# traitement de la page 286 sur 631
# traitement de la page 287 sur 631
# traitement de la page 288 sur 631
# traitement de la page 289 sur 631
# traitement de la page 290 sur 631
# traitement de la page 291 sur 631
# traitement de la page 292 sur 631
# traitement de la page 293 sur 631
# traitement de la page 294 sur 631
# traitement de la page 295 sur 631
# traitement de la page 296 sur 631
# traitement de la page 297 sur 631
# traitement de la page 298 sur 631
# traitement de la page 299 sur 631
# traitement de la page 300 sur 631
# traitement de la page 301 sur 631
# traitement de la page 302 sur 631
# traitement de la page 303 sur 631
# traitement de la page 304 sur 631
# traitement de la page 305 sur 631
# traitement de la page 306 sur 631
# traitement de la page 307 sur 631
# traitement de la page 308 sur 631
# traitement de la page 309 sur 631
# traitement de la page 310 sur 631
# traitement de la page 311 sur 631
# traitement de la page 312 sur 631
# traitement de la page 313 sur 631
# traitement de la page 314 sur 631
# traitement de la page 315 sur 631
# traitement de la page 316 sur 631
# traitement de la page 317 sur 631
# traitement de la page 318 sur 631
# traitement de la page 319 sur 631
# traitement de la page 320 sur 631
# traitement de la page 321 sur 631
# traitement de la page 322 sur 631
# traitement de la page 323 sur 631
# traitement de la page 324 sur 631
# traitement de la page 325 sur 631
# traitement de la page 326 sur 631
# traitement de la page 327 sur 631
# traitement de la page 328 sur 631
# traitement de la page 329 sur 631
# traitement de la page 330 sur 631
# traitement de la page 331 sur 631
# traitement de la page 332 sur 631
# traitement de la page 333 sur 631
# traitement de la page 334 sur 631
# traitement de la page 335 sur 631
# traitement de la page 336 sur 631
# traitement de la page 337 sur 631
# traitement de la page 338 sur 631
# traitement de la page 339 sur 631
# traitement de la page 340 sur 631
# traitement de la page 341 sur 631
# traitement de la page 342 sur 631
# traitement de la page 343 sur 631
# traitement de la page 344 sur 631
# traitement de la page 345 sur 631
# traitement de la page 346 sur 631
# traitement de la page 347 sur 631
# traitement de la page 348 sur 631
# traitement de la page 349 sur 631
# traitement de la page 350 sur 631
# traitement de la page 351 sur 631
# traitement de la page 352 sur 631
# traitement de la page 353 sur 631
# traitement de la page 354 sur 631
# traitement de la page 355 sur 631
# traitement de la page 356 sur 631
# traitement de la page 357 sur 631
# traitement de la page 358 sur 631
# traitement de la page 359 sur 631
# traitement de la page 360 sur 631
# traitement de la page 361 sur 631
# traitement de la page 362 sur 631
# traitement de la page 363 sur 631
# traitement de la page 364 sur 631
# traitement de la page 365 sur 631
# traitement de la page 366 sur 631
# traitement de la page 367 sur 631
# traitement de la page 368 sur 631
# traitement de la page 369 sur 631
# traitement de la page 370 sur 631
# traitement de la page 371 sur 631
# traitement de la page 372 sur 631
# traitement de la page 373 sur 631
# traitement de la page 374 sur 631
# traitement de la page 375 sur 631
# traitement de la page 376 sur 631
# traitement de la page 377 sur 631
# traitement de la page 378 sur 631
# traitement de la page 379 sur 631
# traitement de la page 380 sur 631
# traitement de la page 381 sur 631
# traitement de la page 382 sur 631
# traitement de la page 383 sur 631
# traitement de la page 384 sur 631
# traitement de la page 385 sur 631
# traitement de la page 386 sur 631
# traitement de la page 387 sur 631
# traitement de la page 388 sur 631
# traitement de la page 389 sur 631
# traitement de la page 390 sur 631
# traitement de la page 391 sur 631
# traitement de la page 392 sur 631
# traitement de la page 393 sur 631
# traitement de la page 394 sur 631
# traitement de la page 395 sur 631
# traitement de la page 396 sur 631
# traitement de la page 397 sur 631
# traitement de la page 398 sur 631
# traitement de la page 399 sur 631
# traitement de la page 400 sur 631
# traitement de la page 401 sur 631
# traitement de la page 402 sur 631
# traitement de la page 403 sur 631
# traitement de la page 404 sur 631
# traitement de la page 405 sur 631
# traitement de la page 406 sur 631
# traitement de la page 407 sur 631
# traitement de la page 408 sur 631
# traitement de la page 409 sur 631
# traitement de la page 410 sur 631
# traitement de la page 411 sur 631
# traitement de la page 412 sur 631
# traitement de la page 413 sur 631
# traitement de la page 414 sur 631
# traitement de la page 415 sur 631
# traitement de la page 416 sur 631
# traitement de la page 417 sur 631
# traitement de la page 418 sur 631
# traitement de la page 419 sur 631
# traitement de la page 420 sur 631
# traitement de la page 421 sur 631
# traitement de la page 422 sur 631
# traitement de la page 423 sur 631
# traitement de la page 424 sur 631
# traitement de la page 425 sur 631
# traitement de la page 426 sur 631
# traitement de la page 427 sur 631
# traitement de la page 428 sur 631
# traitement de la page 429 sur 631
# traitement de la page 430 sur 631
# traitement de la page 431 sur 631
# traitement de la page 432 sur 631
# traitement de la page 433 sur 631
# traitement de la page 434 sur 631
# traitement de la page 435 sur 631
# traitement de la page 436 sur 631
# traitement de la page 437 sur 631
# traitement de la page 438 sur 631
# traitement de la page 439 sur 631
# traitement de la page 440 sur 631
# traitement de la page 441 sur 631
# traitement de la page 442 sur 631
# traitement de la page 443 sur 631
# traitement de la page 444 sur 631
# traitement de la page 445 sur 631
# traitement de la page 446 sur 631
# traitement de la page 447 sur 631
# traitement de la page 448 sur 631
# traitement de la page 449 sur 631
# traitement de la page 450 sur 631
# traitement de la page 451 sur 631
# traitement de la page 452 sur 631
# traitement de la page 453 sur 631
# traitement de la page 454 sur 631
# traitement de la page 455 sur 631
# traitement de la page 456 sur 631
# traitement de la page 457 sur 631
# traitement de la page 458 sur 631
# traitement de la page 459 sur 631
# traitement de la page 460 sur 631
# traitement de la page 461 sur 631
# traitement de la page 462 sur 631
# traitement de la page 463 sur 631
# traitement de la page 464 sur 631
# traitement de la page 465 sur 631
# traitement de la page 466 sur 631
# traitement de la page 467 sur 631
# traitement de la page 468 sur 631
# traitement de la page 469 sur 631
# traitement de la page 470 sur 631
# traitement de la page 471 sur 631
# traitement de la page 472 sur 631
# traitement de la page 473 sur 631
# traitement de la page 474 sur 631
# traitement de la page 475 sur 631
# traitement de la page 476 sur 631
# traitement de la page 477 sur 631
# traitement de la page 478 sur 631
# traitement de la page 479 sur 631
# traitement de la page 480 sur 631
# traitement de la page 481 sur 631
# traitement de la page 482 sur 631
# traitement de la page 483 sur 631
# traitement de la page 484 sur 631
# traitement de la page 485 sur 631
# traitement de la page 486 sur 631
# traitement de la page 487 sur 631
# traitement de la page 488 sur 631
# traitement de la page 489 sur 631
# traitement de la page 490 sur 631
# traitement de la page 491 sur 631
# traitement de la page 492 sur 631
# traitement de la page 493 sur 631
# traitement de la page 494 sur 631
# traitement de la page 495 sur 631
# traitement de la page 496 sur 631
# traitement de la page 497 sur 631
# traitement de la page 498 sur 631
# traitement de la page 499 sur 631
# traitement de la page 500 sur 631
# traitement de la page 501 sur 631
# traitement de la page 502 sur 631
# traitement de la page 503 sur 631
# traitement de la page 504 sur 631
# traitement de la page 505 sur 631
# traitement de la page 506 sur 631
# traitement de la page 507 sur 631
# traitement de la page 508 sur 631
# traitement de la page 509 sur 631
# traitement de la page 510 sur 631
# traitement de la page 511 sur 631
# traitement de la page 512 sur 631
# traitement de la page 513 sur 631
# traitement de la page 514 sur 631
# traitement de la page 515 sur 631
# traitement de la page 516 sur 631
# traitement de la page 517 sur 631
# traitement de la page 518 sur 631
# traitement de la page 519 sur 631
# traitement de la page 520 sur 631
# traitement de la page 521 sur 631
# traitement de la page 522 sur 631
# traitement de la page 523 sur 631
# traitement de la page 524 sur 631
# traitement de la page 525 sur 631
# traitement de la page 526 sur 631
# traitement de la page 527 sur 631
# traitement de la page 528 sur 631
# traitement de la page 529 sur 631
# traitement de la page 530 sur 631
# traitement de la page 531 sur 631
# traitement de la page 532 sur 631
# traitement de la page 533 sur 631
# traitement de la page 534 sur 631
# traitement de la page 535 sur 631
# traitement de la page 536 sur 631
# traitement de la page 537 sur 631
# traitement de la page 538 sur 631
# traitement de la page 539 sur 631
# traitement de la page 540 sur 631
# traitement de la page 541 sur 631
# traitement de la page 542 sur 631
# traitement de la page 543 sur 631
# traitement de la page 544 sur 631
# traitement de la page 545 sur 631
# traitement de la page 546 sur 631
# traitement de la page 547 sur 631
# traitement de la page 548 sur 631
# traitement de la page 549 sur 631
# traitement de la page 550 sur 631
# traitement de la page 551 sur 631
# traitement de la page 552 sur 631
# traitement de la page 553 sur 631
# traitement de la page 554 sur 631
# traitement de la page 555 sur 631
# traitement de la page 556 sur 631
# traitement de la page 557 sur 631
# traitement de la page 558 sur 631
# traitement de la page 559 sur 631
# traitement de la page 560 sur 631
# traitement de la page 561 sur 631
# traitement de la page 562 sur 631
# traitement de la page 563 sur 631
# traitement de la page 564 sur 631
# traitement de la page 565 sur 631
# traitement de la page 566 sur 631
# traitement de la page 567 sur 631
# traitement de la page 568 sur 631
# traitement de la page 569 sur 631
# traitement de la page 570 sur 631
# traitement de la page 571 sur 631
# traitement de la page 572 sur 631
# traitement de la page 573 sur 631
# traitement de la page 574 sur 631
# traitement de la page 575 sur 631
# traitement de la page 576 sur 631
# traitement de la page 577 sur 631
# traitement de la page 578 sur 631
# traitement de la page 579 sur 631
# traitement de la page 580 sur 631
# traitement de la page 581 sur 631
# traitement de la page 582 sur 631
# traitement de la page 583 sur 631
# traitement de la page 584 sur 631
# traitement de la page 585 sur 631
# traitement de la page 586 sur 631
# traitement de la page 587 sur 631
# traitement de la page 588 sur 631
# traitement de la page 589 sur 631
# traitement de la page 590 sur 631
# traitement de la page 591 sur 631
# traitement de la page 592 sur 631
# traitement de la page 593 sur 631
# traitement de la page 594 sur 631
# traitement de la page 595 sur 631
# traitement de la page 596 sur 631
# traitement de la page 597 sur 631
# traitement de la page 598 sur 631
# traitement de la page 599 sur 631
# traitement de la page 600 sur 631
# traitement de la page 601 sur 631
# traitement de la page 602 sur 631
# traitement de la page 603 sur 631
# traitement de la page 604 sur 631
# traitement de la page 605 sur 631
# traitement de la page 606 sur 631
# traitement de la page 607 sur 631
# traitement de la page 608 sur 631
# traitement de la page 609 sur 631
# traitement de la page 610 sur 631
# traitement de la page 611 sur 631
# traitement de la page 612 sur 631
# traitement de la page 613 sur 631
# traitement de la page 614 sur 631
# traitement de la page 615 sur 631
# traitement de la page 616 sur 631
# traitement de la page 617 sur 631
# traitement de la page 618 sur 631
# traitement de la page 619 sur 631
# traitement de la page 620 sur 631
# traitement de la page 621 sur 631
# traitement de la page 622 sur 631
# traitement de la page 623 sur 631
# traitement de la page 624 sur 631
# traitement de la page 625 sur 631
# traitement de la page 626 sur 631
# traitement de la page 627 sur 631
# traitement de la page 628 sur 631
# traitement de la page 629 sur 631
# traitement de la page 630 sur 631
# traitement de la page 631 sur 631

# %% [markdown]
# ## Contrôle de la longueur des tableaux

# %%
print(f"longueur liste conseillers : {len(liste_conseillers)}")
print(f"longueur liste_villes : {len(liste_villes)}")
print(f"longueur liste_telephone : {len(liste_telephone)}")
print(f"longueur liste_lien_photo : {len(liste_lien_photo)}")
print(f"longueur liste_lien_minisite : {len(liste_lien_minisite)}")
# Out:
# longueur liste conseillers : 5658
# longueur liste_villes : 5658
# longueur liste_telephone : 5658
# longueur liste_lien_photo : 5658
# longueur liste_lien_minisite : 5658

# %% [markdown]
# ## Création du dataframe DF

# %%
df = pd.DataFrame({'conseillers' : liste_conseillers, 'telephone' : liste_telephone, 
                   'ville' : liste_villes, 'photo' : liste_lien_photo, 'minisite' : liste_lien_minisite})

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Suppression des espaces des numéros de téléphone

# %%
df['telephone'] = df['telephone'].str.replace(' ', '')

# %% [markdown]
# ## Retraitement de la colonne Ville

# %%
df['ville1'] = df['ville'].str.replace(' et alentours', '')
df[['ville_nom', 'code_postal']] = df['ville'].str.extract(r'(\D+)\s*\((\d+)\)')
df.drop('ville', axis=1, inplace=True)
df.drop('ville1', axis=1, inplace=True)

# %% [markdown]
# ## Retaitement code postal et création colonnes département

# %%
df['département'] = df['code_postal'].str.slice(0, 2)

# %% [markdown]
# ## Création de la colonne région

# %%
regions_dict = {
    'Auvergne-Rhône-Alpes': ['01', '03', '07', '15', '26', '38', '42', '43', '63', '69', '73', '74'],
    'Bourgogne-Franche-Comté': ['21', '25', '39', '58', '70', '71', '89', '90'],
    'Bretagne': ['22', '29', '35', '56'],
    'Centre-Val de Loire': ['18', '28', '36', '37', '41', '45'],
    'Corse': ['2A', '2B'],
    'Grand Est': ['08', '10', '51', '52', '54', '55', '57', '67', '68', '88'],
    'Hauts-de-France': ['02', '59', '60', '62', '80'],
    'Île-de-France': ['75', '77', '78', '91', '92', '93', '94', '95'],
    'Normandie': ['14', '27', '50', '61', '76'],
    'Nouvelle-Aquitaine': ['16', '17', '19', '23', '24', '33', '40', '47', '64', '79', '86', '87'],
    'Occitanie': ['09', '11', '12', '30', '31', '32', '34', '46', '48', '65', '66', '81', '82'],
    'Pays de la Loire': ['44', '49', '53', '72', '85'],
    'Provence-Alpes-Côte d\'Azur': ['04', '05', '06', '13', '83', '84'],
    'Corse': ['20'],
    'DOM/TOM': ['97']
}

flat_regions_dict = {dept: region for region, depts in regions_dict.items() for dept in depts}

# Supposons que df['departement'] contient des codes de département
df['region'] = df['département'].map(flat_regions_dict)

# %% [markdown]
# ## Contôle des valeurs nulles

# %%
df.isnull().sum()
# Out:
# conseillers    0
# telephone      0
# photo          0
# minisite       0
# ville_nom      0
# code_postal    0
# département    0
# region         0
# dtype: int64

# %% [markdown]
# # Génération du fichier excel

# %%
df.to_csv('contacts_safti_excel.csv')
print('Le fichier a été créé avec succés')
